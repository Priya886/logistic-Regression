# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
bank = pd.read_csv('I:\Assigment - Data Science\logistic Regression/bank-full.csv',sep=';')

# %%
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
labelencoder = LabelEncoder()
bank.iloc[:, 2] = labelencoder.fit_transform(bank.iloc[:,2])

# %%
bank
# Out:
#        age           job  marital  education default  balance housing loan  \
# 0       58    management        1   tertiary      no     2143     yes   no
# 1       44    technician        2  secondary      no       29     yes   no
# 2       33  entrepreneur        1  secondary      no        2     yes  yes
# 3       47   blue-collar        1    unknown      no     1506     yes   no
# 4       33       unknown        2    unknown      no        1      no   no
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 45206   51    technician        1   tertiary      no      825      no   no
# 45207   71       retired        0    primary      no     1729      no   no
# 45208   72       retired        1  secondary      no     5715      no   no
# 45209   57   blue-collar        1  secondary      no      668      no   no
# 45210   37  entrepreneur        1  secondary      no     2971      no   no
#
# ...

# %%
bank1=bank.copy()

# %%
labelencoder = LabelEncoder()
bank1.iloc[:, 1] = labelencoder.fit_transform(bank1.iloc[:,1])

# %%
bank1
# Out:
#        age  job  marital  education default  balance housing loan    contact  \
# 0       58    4        1   tertiary      no     2143     yes   no    unknown
# 1       44    9        2  secondary      no       29     yes   no    unknown
# 2       33    2        1  secondary      no        2     yes  yes    unknown
# 3       47    1        1    unknown      no     1506     yes   no    unknown
# 4       33   11        2    unknown      no        1      no   no    unknown
# ...    ...  ...      ...        ...     ...      ...     ...  ...        ...
# 45206   51    9        1   tertiary      no      825      no   no   cellular
# 45207   71    5        0    primary      no     1729      no   no   cellular
# 45208   72    5        1  secondary      no     5715      no   no   cellular
# 45209   57    1        1  secondary      no      668      no   no  telephone
# 45210   37    2        1  secondary      no     2971      no   no   cellular
#
# ...

# %%
labelencoder = LabelEncoder()
bank1.iloc[:, 3] = labelencoder.fit_transform(bank1.iloc[:,3])

# %%
bank1
# Out:
#        age  job  marital  education default  balance housing loan    contact  \
# 0       58    4        1          2      no     2143     yes   no    unknown
# 1       44    9        2          1      no       29     yes   no    unknown
# 2       33    2        1          1      no        2     yes  yes    unknown
# 3       47    1        1          3      no     1506     yes   no    unknown
# 4       33   11        2          3      no        1      no   no    unknown
# ...    ...  ...      ...        ...     ...      ...     ...  ...        ...
# 45206   51    9        1          2      no      825      no   no   cellular
# 45207   71    5        0          0      no     1729      no   no   cellular
# 45208   72    5        1          1      no     5715      no   no   cellular
# 45209   57    1        1          1      no      668      no   no  telephone
# 45210   37    2        1          1      no     2971      no   no   cellular
#
# ...

# %%
labelencoder = LabelEncoder()
bank1.iloc[:,4] = labelencoder.fit_transform(bank1.iloc[:,4])

# %%
bank1
# Out:
#        age  job  marital  education  default  balance housing loan    contact  \
# 0       58    4        1          2        0     2143     yes   no    unknown
# 1       44    9        2          1        0       29     yes   no    unknown
# 2       33    2        1          1        0        2     yes  yes    unknown
# 3       47    1        1          3        0     1506     yes   no    unknown
# 4       33   11        2          3        0        1      no   no    unknown
# ...    ...  ...      ...        ...      ...      ...     ...  ...        ...
# 45206   51    9        1          2        0      825      no   no   cellular
# 45207   71    5        0          0        0     1729      no   no   cellular
# 45208   72    5        1          1        0     5715      no   no   cellular
# 45209   57    1        1          1        0      668      no   no  telephone
# 45210   37    2        1          1        0     2971      no   no   cellular
#
# ...

# %%
labelencoder = LabelEncoder()
bank1.iloc[:,6]= labelencoder.fit_transform(bank1.iloc[:,6])

# %%
labelencoder = LabelEncoder()
bank1.iloc[:,7] = labelencoder.fit_transform(bank1.iloc[:,7])

# %%
labelencoder = LabelEncoder()
bank1.iloc[:,8] = labelencoder.fit_transform(bank1.iloc[:,8])

# %%
labelencoder = LabelEncoder()
bank1.iloc[:,10] = labelencoder.fit_transform(bank1.iloc[:,10])

# %%
labelencoder = LabelEncoder()
bank1.iloc[:,15] = labelencoder.fit_transform(bank1.iloc[:,15])

# %%
labelencoder = LabelEncoder()
bank1.iloc[:,16] = labelencoder.fit_transform(bank1.iloc[:,16])

# %%
bank1
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
# ...

# %%
bank1.corr()
# Out:
#                 age       job   marital  education   default   balance  \
# age        1.000000 -0.021868 -0.403240  -0.106807 -0.017879  0.097783
# job       -0.021868  1.000000  0.062045   0.166707 -0.006853  0.018232
# marital   -0.403240  0.062045  1.000000   0.108576 -0.007023  0.002122
# education -0.106807  0.166707  0.108576   1.000000 -0.010718  0.064514
# default   -0.017879 -0.006853 -0.007023  -0.010718  1.000000 -0.066745
# balance    0.097783  0.018232  0.002122   0.064514 -0.066745  1.000000
# housing   -0.185513 -0.125363 -0.016096  -0.090790 -0.006025 -0.068768
# loan      -0.015655 -0.033004 -0.046893  -0.048574  0.077234 -0.084350
# contact    0.026221 -0.082063 -0.039201  -0.110928  0.015404 -0.027273
# day       -0.009120  0.022856 -0.005261   0.022671  0.009424  0.004503
# month     -0.042357 -0.092870 -0.006991  -0.057304  0.011486  0.019777
# duration  -0.004648  0.004744  0.011852   0.001935 -0.010021  0.021560
# ...

# %%
##sns.set_style(style = 'darkgrid')
##sns.pairplot(bank1)

# %%
bank1.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0

# %%
bank1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  int32
#  2   marital    45211 non-null  int32
#  3   education  45211 non-null  int32
#  4   default    45211 non-null  int32
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  int32
#  7   loan       45211 non-null  int32
#  8   contact    45211 non-null  int32
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  int32
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  int32
#  16  y          45211 non-null  int32
# dtypes: int32(10), int64(7)
# memory usage: 4.1 MB

# %%
## Dividing your data into Input and Output variable

# %%
bank1 = bank1[['housing','contact','duration','pdays','age','job','marital','education','default','balance','loan','day','month','campaign','previous','poutcome']]

# %%
bank1
# Out:
#        housing  contact  duration  pdays  age  job  marital  education  \
# 0            1        2       261     -1   58    4        1          2
# 1            1        2       151     -1   44    9        2          1
# 2            1        2        76     -1   33    2        1          1
# 3            1        2        92     -1   47    1        1          3
# 4            0        2       198     -1   33   11        2          3
# ...        ...      ...       ...    ...  ...  ...      ...        ...
# 45206        0        0       977     -1   51    9        1          2
# 45207        0        0       456     -1   71    5        0          0
# 45208        0        0      1127    184   72    5        1          1
# 45209        0        1       508     -1   57    1        1          1
# 45210        0        0       361    188   37    2        1          1
#
#        default  balance  loan  day  month  campaign  previous  poutcome
# ...

# %%
X = bank1.iloc[:,0:3]
Y = bank1.iloc[:,-1]

# %%
classifier = LogisticRegression()
classifier.fit(X,Y)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = classifier.predict(X)

# %%
y_pred_df= pd.DataFrame({'actual': Y,
                         'predicted_prob': classifier.predict(X)})

# %%
y_pred_df
# Out:
#        actual  predicted_prob
# 0           3               3
# 1           3               3
# 2           3               3
# 3           3               3
# 4           3               3
# ...       ...             ...
# 45206       3               3
# 45207       3               3
# 45208       2               3
# 45209       3               3
# 45210       1               3
#
# [45211 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y,y_pred)
print(confusion_matrix)
# Out:
# [[    0     0     0  4901]
#  [    0     0     0  1840]
#  [    0     0     0  1511]
#  [    0     0     0 36959]]

# %%
from sklearn.metrics import classification_report
print(classification_report(Y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      4901
#            1       0.00      0.00      0.00      1840
#            2       0.00      0.00      0.00      1511
#            3       0.82      1.00      0.90     36959
#
#     accuracy                           0.82     45211
#    macro avg       0.20      0.25      0.22     45211
# weighted avg       0.67      0.82      0.74     45211
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, threshold = roc_curve(Y,classifier.predict_proba(X)[[0:3]])

auc = roc_auc_score(Y, y_pred)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red', label='logit model ( area  = %0.2f)'%auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
# Out:
#   File "<ipython-input-46-6983ec0b19a2>", line 4
#     fpr, tpr, threshold = roc_curve(Y,classifier.predict_proba(X)[[0:3]])
#                                                                     ^
# SyntaxError: invalid syntax
